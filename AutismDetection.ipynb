# %%
import os
from preprocess import preprocess

# %%
# !git clone https://github.com/shadunts/autism_screening_adult
os.chdir('autism_screening_adult')
# Out:
# Cloning into 'autism_screening_adult'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 10 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 47.81 KiB | 1.84 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
my_df = preprocess()
# Out:
# /content/autism_screening_adult/preprocess.py:37: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[binary_columns] = df[binary_columns].applymap(lambda x: 1 if x.lower() == 'yes' else 0)

# %%
my_df.to_csv('data_preprocessed.csv', header=True, index=False)
